# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

daniela = pd.read_csv('/data3/VBT_SCZ/GMV/results/ALL_daniela_full_extracted_features.csv')
traditional = pd.read_csv('/data3/VBT_SCZ/GMV/results/ALL_traditional_full_extracted_features.csv')

# %%
import seaborn as sns

plt.subplot(121)
plt.scatter(daniela['VAR_FCD'], daniela['GBC'])
plt.subplot(122)
plt.scatter(traditional['VAR_FCD'], traditional['GBC'])

# %%
daniela
# Out:
#     Unnamed: 0         pid       GBC   VAR_FCD  L.BSTS_FC  L.CACG_FC  \
# 0            0        1272  0.256880  0.006584   0.156384   0.105514
# 1            0  2019052302  0.292533  0.003751   0.153744   0.178574
# 2            0        1280  0.508458  0.004305   0.307414   0.310683
# 3            0        1273  0.366634  0.004760   0.208024   0.203197
# 4            0  2015120501  0.358611  0.006390   0.208826   0.076699
# 5            0  2019012101  0.233196  0.002526   0.122669   0.092508
# 6            0  2015060902  0.097211  0.011631   0.081350  -0.005025
# 7            0  2015111402  0.208088  0.003525   0.090071   0.114841
# 8            0        1860  0.279269  0.006002   0.093111   0.178936
# 9            0  2019012402  0.288315  0.005448   0.159043   0.181519
# 10           0        1858  0.337257  0.006013   0.194571   0.125302
# 11           0        1269  0.233341  0.002506   0.111643   0.163108
# 12           0        1856  0.520069  0.010607   0.303676   0.280441
# ...

# %%
daniela
# Out:
#     Unnamed: 0         pid       GBC   VAR_FCD  L.BSTS_FC  L.CACG_FC  \
# 0            0        1272  0.255156  0.006584   0.155335   0.104806
# 1            0  2019052302  0.291140  0.003751   0.153012   0.177723
# 2            0        1280  0.505046  0.004305   0.305351   0.308598
# 3            0        1273  0.364173  0.004760   0.206628   0.201833
# 4            0  2015120501  0.356904  0.006390   0.207831   0.076334
# 5            0  2019012101  0.232085  0.002526   0.122085   0.092068
# 6            0  2015060902  0.096748  0.011631   0.080962  -0.005001
# 7            0  2015111402  0.207097  0.003525   0.089642   0.114294
# 8            0        1860  0.277395  0.006002   0.092486   0.177736
# 9            0  2019012402  0.286942  0.005448   0.158285   0.180655
# 10           0        1858  0.334994  0.006013   0.193266   0.124461
# 11           0        1269  0.231775  0.002506   0.110894   0.162013
# 12           0        1856  0.517902  0.010607   0.302411   0.279272
# ...

# %%
to_plot = ['GBC', 'VAR_FCD']
sns.violinplot(traditional[to_plot])
# Out:
# <Axes: >

# %%
to_plot = ['GBC', 'VAR_FCD']
sns.violinplot(daniela[to_plot])
# Out:
# <Axes: >

# %%
traditional
# Out:
#     Unnamed: 0         pid       GBC   VAR_FCD  L.BSTS_FC  L.CACG_FC  \
# 0            0        1272  0.018524  0.002382   0.005563   0.035500
# 1            0  2019052302  0.010322  0.003393  -0.005253   0.029237
# 2            0        1280  0.039910  0.001923   0.012980   0.048639
# 3            0        1273  0.022690  0.002754   0.009998   0.014423
# 4            0  2015120501  0.014120  0.003052   0.013211   0.001377
# 5            0  2019012101  0.009431  0.002582   0.015254   0.018329
# 6            0  2015060902  0.006350  0.012869   0.002260  -0.018186
# 7            0  2015111402  0.006764  0.002948  -0.002503   0.016082
# 8            0        1860  0.019422  0.007297  -0.001676   0.019808
# 9            0  2019012402  0.015333  0.004010   0.020162   0.036898
# 10           0        1858  0.087320  0.005995   0.044841   0.060849
# 11           0        1269  0.013287  0.003938   0.000660   0.028506
# 12           0        1856  0.051762  0.006076   0.034793   0.073269
# ...
